# %%
from collections import Counter
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource
import pandas

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a960234-b77b-4f67-b91e-b5a1f5b74460">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure()

# %%
def get_year(date_str):
    return date_str.split('/').pop()

crashes_df = pandas.read_csv('./airplane-crashes.csv')
years_df = crashes_df['Date'].apply(get_year)
crashes_per_year = Counter(years_df)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8a4762e9-674e-4c09-be83-6f769f793acf"></div>
# </div>
